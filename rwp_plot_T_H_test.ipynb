# %% [markdown]
# # Radar Wind Profiler Time-Hieght Plot
#
# **ARM Radar Wind Profiler data time-heoght plotting and analysis test codes.**
#
# **Hungjui Yu 20220503**

# %%
# %reset
# Out:
# Once deleted, variables cannot be recovered. Proceed (y/[n])? y

# %%
import sys
import time
import datetime as dt
from netCDF4 import Dataset # MFDataset
import numpy as np
import xarray as xr
# from scipy.interpolate import interpn

# import cartopy.crs as ccrs
# import cartopy.feature as cfeat
# import cartopy.io.img_tiles as cimgt

# import matplotlib as mpl
# import matplotlib.pyplot as plt
# import matplotlib.cm as cm
# from matplotlib.colors import ( from_levels_and_colors, Normalize ) 


# from metpy.plots import ctables
# import metpy.calc as mpcalc

# %% [markdown]
# ## Open RWP data:

# %%
data_path_full = '/home/hyu/2scratch2/DATA_DOE_CACTI_cases/DATA_ARM_CACTI_Radar_Wind_Profiler_RWP/201812_201901/cor1290rwpwindconM1.a1.20190125.000008.cdf'

ds_rwp = xr.open_dataset(data_path_full)
ds_rwp
# Out:
# <xarray.Dataset>
# Dimensions:      (time: 24, range_gate: 75, power: 2)
# Coordinates:
#   * time         (time) datetime64[ns] 2019-01-25T00:00:08 ... 2019-01-25T23:...
#   * range_gate   (range_gate) float32 0.0 1.0 2.0 3.0 ... 71.0 72.0 73.0 74.0
#   * power        (power) float32 1.0 2.0
# Data variables: (12/60)
#     base_time    datetime64[ns] ...
#     time_offset  (time) datetime64[ns] ...
#     height_p     (range_gate, power) float32 ...
#     spd          (time, range_gate, power) float32 ...
#     dir          (time, range_gate, power) float32 ...
#     u_wind       (time, range_gate, power) float32 ...
#     ...           ...
#     elevation2   (power) float32 ...
#     elevation3   (power) float32 ...
#     elevation4   (power) float32 ...
#     lat          float32 ...
#     lon          float32 ...
#     alt          float32 ...
# Attributes: (12/20)
#     command_line:            rwp_ingest -n 1290rwp -s cor -f M1
# ...

# %%
ds_rwp.u_wind.isel(time=22, power=1).plot()
