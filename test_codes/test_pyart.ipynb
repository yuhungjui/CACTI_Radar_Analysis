# %% [markdown]
# # Test some PyART

# %%
# %reset
# Out:
# /usr/local/anaconda3/lib/python3.8/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# Once deleted, variables cannot be recovered. Proceed (y/[n])? y

# %%
import sys
import matplotlib.pyplot as plt
import pyart
# Out:
# /usr/local/anaconda3/lib/python3.8/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
modules_path = '/home/hyu/MODULES/dealias/unravel'
if ( modules_path not in sys.path ):     
    sys.path = [modules_path] + sys.path
    print(sys.path)

print(sys.path)
# Out:
# ['/home/hyu/MODULES/dealias/unravel', '/home/mrocque/research/relampago/unravel', '/home/hyu/Research_Test/Radar_analysis_CACTI/test_codes', '/usr/local/anaconda3/lib/python38.zip', '/usr/local/anaconda3/lib/python3.8', '/usr/local/anaconda3/lib/python3.8/lib-dynload', '', '/home/hyu/.local/lib/python3.8/site-packages', '/home/hyu/Research_Test/TINT', '/usr/local/anaconda3/lib/python3.8/site-packages', '/usr/local/anaconda3/lib/python3.8/site-packages/csu_radartools-1.3.0.dev0-py3.8-linux-x86_64.egg', '/usr/local/anaconda3/src/TINT', '/usr/local/anaconda3/lib/python3.8/site-packages/IPython/extensions', '/home/hyu/.ipython']
# /usr/local/anaconda3/lib/python3.8/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
# ...

# %%
import dealias
# Out:
# /usr/local/anaconda3/lib/python3.8/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
# radar = pyart.io.read('/home/hyu/2scratch2/DATA_DOE_CACTI_cases/DATA_Primary_Cases/20190125/QCed/corcsapr2cfrppiqcM1.b1.20190125.220003.csuqc.pyart_dealias.nc')
radar = pyart.io.read('/home/hyu/2scratch2/DATA_DOE_CACTI_cases/DATA_Primary_Cases/20190125/QCed_RadxConvert/cfrad.20190125_220003.000_to_20190125_220623.809_CSAPR2_PPI.nc')
# Out:
# /usr/local/anaconda3/lib/python3.8/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
display = pyart.graph.RadarDisplay(radar)
fig = plt.figure()
ax = fig.add_subplot(111)
display.plot_ppi('DBZ', sweep=5, vmin=-32, vmax=64.)
display.plot_range_rings([10, 20, 30, 40])
display.plot_cross_hair(5.)
plt.show()
# Out:
# /usr/local/anaconda3/lib/python3.8/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
display.plot_ppi('DBZ')
# Out:
# /usr/local/anaconda3/lib/python3.8/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
